# %% [markdown]
# <img src="https://drive.google.com/uc?id=1v_9uDXBEzzBbC3NOxpGHj2UHrJx6rhCY" width= "140" height="80" align="right"  style="float:right;margin: auto;">
#
# # <center><u>**ARCANUM**</u></center>

# %% [markdown]
# # Assets Link :
# https://drive.google.com/drive/folders/1NOWicPYTJjQxPhPYXCo4IwMgbnlKl3PP?usp=sharing

# %% [markdown]
# **SOLVING PUZZLE :**

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import files

# Put your code here:
i = cv2.imread("/content/Crossword.jpg",cv2.IMREAD_COLOR)
cv2_imshow(i)
font = cv2.FONT_HERSHEY_SIMPLEX
org = (200, 130)
org1 = (345, 135)
org2 = (400, 135)
org3 = (470, 135)
org4 = (200, 200)
org5 = (200, 270)
org6 = (200, 340)
org7 = (200, 410)
org8 = (60, 200)
org9 = (270, 200)
org10 = (340, 200)
org11 = (400, 200)
org12 = (460, 200)
org13 = (340, 270)
org14 = (340, 410)
org15 = (270, 340)
org16 = (400, 340)
fontScale = 3
color = (0, 255, 0)
thickness = 1
i = cv2.putText(i, 'c', org, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'f', org1, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'f', org2, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'i', org3, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'a', org4, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'n', org5, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'd', org6, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'l', org7, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'a', org8, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'g', org9, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'r', org10, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'a', org11, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'm', org12, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'a', org13, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'e', org14, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'o', org15, font, fontScale, color, thickness, cv2.LINE_AA)
i = cv2.putText(i, 'e', org16, font, fontScale, color, thickness, cv2.LINE_AA)
cv2_imshow(i)
# Out:
# <PIL.Image.Image image mode=RGB size=660x567 at 0x7F17B5EA6F50>
# <PIL.Image.Image image mode=RGB size=660x567 at 0x7F17B5EA6550>

# %% [markdown]
# **FINDING NUMBER :**

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import files

# Put your code here:
i = cv2.imread("/content/Wordmaze.jpg",cv2.IMREAD_COLOR)
cv2_imshow(i)
start_point = (50, 50)
end_point = (100, 400)
start_point1 = (50, 350)
end_point1 = (390, 400)
start_point2 = (320, 300)
end_point2 = (370, 700)
color = (0, 0, 0)
thickness = -1
i = cv2.rectangle(i, start_point, end_point, color, thickness)
i = cv2.rectangle(i, start_point1, end_point1, color, thickness)
i = cv2.rectangle(i, start_point2, end_point2, color, thickness)
cv2_imshow(i)
# Out:
# <PIL.Image.Image image mode=RGB size=721x770 at 0x7F17B4605390>
# <PIL.Image.Image image mode=RGB size=721x770 at 0x7F17B4605350>

# %% [markdown]
# **USE THIS LINK :**     **Place the number in the "_" space provided in the link below and click it.**

# %% [markdown]
#  https://shorturl.at/rNS_9
